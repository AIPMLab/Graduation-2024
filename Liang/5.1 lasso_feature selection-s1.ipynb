# %%
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LassoCV
import pandas as pd
import numpy as np

dataFile = "D:/radiomic1/glioma/csv4/train_t2_s1.csv"
data = pd.read_csv(dataFile)
dataFile_test = "D:/radiomic1/glioma/csv4/test_t2_s1.csv"
data_test = pd.read_csv(dataFile_test)
x = data.iloc[:, 2:]
y = data["label"]
x_test = data_test.iloc[:, 2:]
y_test = data_test["label"]
x.shape
# Out:
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# (127, 965)

# %%
# log函数，以10为底，即lg(-10)至lg(-1)中随机取100个数。
alphas = np.logspace(-10, -1, 100, base=10)
alphas

selector_lasso = LassoCV(alphas=alphas, cv=5, max_iter=int(1e6))
# alphas = alphas即上面生成的数组，cv = 5即5次交叉验证
selector_lasso.fit(x, y)  # 拟合

selector_lasso.alpha_  # 选出最优的a值，此值不可在alphas（即lg(-10)至lg(-1)）的范围内，否则这个边界设置不合理。

selector_lasso.coef_  # 特征系数

x.columns[selector_lasso.coef_ != 0]  # 把不等于0的特征系数挑选出来，删除特征系数=0的无意义特征

x[x.columns[selector_lasso.coef_ != 0]]  # 生成DataFrame

selector_lasso.intercept_  # 截距

selector_lasso.mse_path_.shape  # selector_lasso.mse_path_为每次交叉验证的误差

selector_lasso.mse_path_.mean(axis=1)  # 5次误差的平均值，axis = 1表示列
# Out:
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.563e-01, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.662e-01, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.967e-01, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.405e-01, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.951e-01, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.584e-01, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.286e-01, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.045e-01, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.494e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.905e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.612e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.559e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.703e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.007e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.441e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.981e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.608e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.305e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.059e-02, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.590e-03, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.970e-03, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.654e-03, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.587e-03, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.721e-03, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.019e-03, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.449e-03, tolerance: 2.436e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.171e-01, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.159e-01, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.376e-01, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.748e-01, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.239e-01, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.823e-01, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.485e-01, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.209e-01, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.829e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.990e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.492e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.274e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.283e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.477e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.822e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.291e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.859e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.509e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.224e-02, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.935e-03, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.061e-03, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.540e-03, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.305e-03, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.304e-03, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.492e-03, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.832e-03, tolerance: 2.416e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.310e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.270e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.473e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.831e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.307e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.879e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.529e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.244e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.012e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.223e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.682e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.428e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.408e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.579e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.905e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.358e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.914e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.553e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.260e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.023e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.296e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.730e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.460e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.429e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.593e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.915e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.811e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.758e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.893e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.177e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.589e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.107e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.716e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.396e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.135e-01, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.229e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.498e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.090e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.946e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.015e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.259e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.645e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.147e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.742e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.413e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.147e-02, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.303e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.547e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.123e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.967e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.029e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.268e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.651e-03, tolerance: 2.431e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.694e-01, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.855e-01, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.266e-01, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.821e-01, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.473e-01, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.193e-01, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.662e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.831e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.354e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.158e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.189e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.401e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.761e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.242e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.820e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.477e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.199e-02, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.731e-03, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.896e-03, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.407e-03, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.198e-03, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.217e-03, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.421e-03, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.775e-03, tolerance: 2.409e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.063e+00, tolerance: 3.031e-03
#   model = cd_fast.enet_coordinate_descent(
# array([1086.72133771, 1181.65362492, 1306.16521232, 1393.20740137,
#        1456.79938332, 1503.81056062, 1538.29536491, 1560.31859687,
#        1577.7220251 , 1591.8656428 , 1603.93873866, 1614.59204991,
#        1623.67919026, 1630.19439552, 1635.25342867, 1639.44148186,
#        1642.43835866, 1644.45649786, 1646.03207079, 1647.28974336,
#        1648.30102607, 1649.11728184, 1649.7775277 , 1650.31204713,
#        1650.5890274 , 1650.8135732 , 1650.96366846, 1650.96322078,
#        1650.96258836, 1650.96191735, 1650.96126676, 1650.96099471,
#        1650.96068088, 1650.96064935, 1650.96106265, 1650.96163998,
#        1650.9615825 , 1650.96061889, 1650.9597412 , 1650.95929148,
#        1650.95915955, 1650.95939757, 1650.95949876, 1650.95972915,
#        1650.95995935, 1650.9603596 , 1650.96308839, 1650.96595128,
#        1650.96968814, 1650.97315383, 1650.97573593, 1650.97764155,
#        1650.97905913, 1650.98056859, 1650.98203212, 1650.98337853,
#        1650.98461426, 1650.98579534, 1650.9865239 , 1650.98710893,
#        1650.98763998, 1650.9882338 , 1650.98869896, 1650.98923422,
#        1650.989809  , 1650.99042121, 1650.99085304, 1650.99132923,
#        1650.99189789, 1650.99235805, 1650.99277993, 1650.99315412,
#        1650.99351689, 1650.99382156, 1650.99407616, 1650.99426088,
#        1650.99441183, 1650.99451715, 1650.99458797, 1650.9946437 ,
#        1650.99468075, 1650.99471028, 1650.99472954, 1650.99475159,
#        1650.99476202, 1650.99477863, 1650.99478995, 1650.99479867,
#        1650.99480541, 1650.99480999, 1650.99481309, 1650.99481461,
#        1650.99481493, 1650.99481459, 1650.994814  , 1650.99481317,
#        1650.99481135, 1650.99481074, 1650.99480854, 1650.99480623])

# %%
# # 保存所选特征到CSV文件
selected_features_df = x[x.columns[selector_lasso.coef_ != 0]]
selected_features_test = x_test[x_test.columns[selector_lasso.coef_ != 0]]

labels = data["label"]  # 假设标签列名为'label'，请根据实际情况修改
labels_test = data_test["label"]

# 将标签列与选择的特征数据框合并
selected_features_with_labels = pd.concat(
    [selected_features_df, labels], axis=1)
selected_features_with_labels_test = pd.concat(
    [selected_features_test, y_test], axis=1)

# 保存合并后的数据框为CSV文件
selected_features_with_labels.to_csv('D:/radiomic1/glioma/tcsv/' +
                                     
                                     
                                     'lasso_features_train_t2_s1.csv', index=False)
selected_features_with_labels_test.to_csv(
    'D:/radiomic1/glioma/tcsv/'+'lasso_features_test_t2_s1.csv', index=False)

# %%
# 图一

MSEs_mean = selector_lasso.mse_path_.mean(axis=1)
MSEs_std = selector_lasso.mse_path_.std(axis=1)

plt.figure()
plt.errorbar(selector_lasso.alphas_, MSEs_mean, yerr=MSEs_std  # 第一个表示x轴，第二表示y轴，第三表示误差范围即蓝线误差棒
             , fmt="o"  # 数据点标记
             , ms=3  # 数据点大小
             , mfc="r"  # 数据点颜色
             , mec="r"  # 数据点边缘颜色
             , ecolor="lightblue"  # 误差棒颜色
             , elinewidth=2  # 误差棒线宽
             , capsize=4  # 误差棒边界线长度
             , capthick=1  # 误差棒边界线厚度
             )
plt.semilogx()  # 画横坐标
plt.axvline(selector_lasso.alpha_, color="black",
            ls="--")  # 在最小MSE值，即最佳Lambda画竖线
plt.xlabel("Lambda")  # x轴标签
plt.ylabel("MSE")  # y轴标签
plt.show()  # 展示

# %%
# 提取特征重要性
feature_importances = np.abs(selector_lasso.coef_)

# 创建包含特征名和特征重要性的DataFrame
features_df = pd.DataFrame({
    'Feature Name': x.columns,
    'Importance': feature_importances
})
# 保存整个特征重要性列表到CSV
features_df.to_csv('D:/radiomic1/glioma/csv2/Lasso_feature_importances_s1.csv', index=False)
# 按特征重要性排序
sorted_indices = np.argsort(feature_importances)[::-1]
sorted_feature_names = x.columns[sorted_indices[:10]]
sorted_feature_importances = feature_importances[sorted_indices[:10]]
# 绘图
plt.figure(figsize=(10, 6))
plt.barh(range(len(sorted_feature_names)), sorted_feature_importances)
plt.yticks(range(len(sorted_feature_names)), sorted_feature_names)
plt.xlabel('Feature Importance')
plt.ylabel('Feature Name')
plt.title('Top 10 Important Features')
plt.tight_layout()
plt.show()

# %%
# 图二
coefs = selector_lasso.path(x, y, alphas=alphas, max_iter=1e6)[1].T
plt.figure()
plt.semilogx(selector_lasso.alphas_, coefs, '-')  # 以对数形式画横轴，
plt.axvline(selector_lasso.alpha_, color='black', ls="--")
plt.xlabel('Lambda')
plt.ylabel('Coefficients')
plt.show()
# Out:
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.125e+00, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.340e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.743e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.399e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.272e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.332e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.551e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.906e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.375e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.939e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.582e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.289e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.049e-01, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.541e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.946e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.588e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.727e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.027e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.458e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.995e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.619e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.314e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.066e-02, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\xiao\AppData\Roaming\Python\Python39\site-packages\sklearn\linear_model\_coordinate_descent.py:628: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.652e-03, tolerance: 7.700e-03
#   model = cd_fast.enet_coordinate_descent(
